# %%
pip install composition_stats

# %%
import numpy as np
import pandas as pd
import io
import matplotlib.pyplot as plt
import composition_stats as coda
from sklearn.decomposition import PCA

# %%
from google.colab import files
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9342adbc-3788-416f-b43b-3d02589f492e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9342adbc-3788-416f-b43b-3d02589f492e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
#load data
  
df = pd.read_csv(io.BytesIO(uploaded['atlas.csv']))
print(df)
# Out:
#       Actinomycetaceae  Aerococcus  ...  Xanthomonadaceae  Yersinia et rel.
# 0             0.000021    0.000002  ...          0.000033          0.000179
# 1             0.000016    0.000002  ...          0.000022          0.000134
# 2             0.000033    0.000002  ...          0.000036          0.000200
# 3             0.000017    0.000001  ...          0.000031          0.000131
# 4             0.000020    0.000001  ...          0.000032          0.000124
# ...                ...         ...  ...               ...               ...
# 1001          0.000104    0.000002  ...          0.000145          0.000320
# 1002          0.000208    0.000003  ...          0.000137          0.000284
# 1003          0.000140    0.000002  ...          0.000149          0.000317
# 1004          0.000230    0.000012  ...          0.000224          0.000639
# 1005          0.000028    0.000002  ...          0.000057          0.000161
#
# [1006 rows x 130 columns]

# %% [markdown]
# **Transform data using ilr transformation method**

# %%
df.shape
# Out:
# (1006, 130)

# %%
X = coda.ilr(df)

# %%
X.shape
# Out:
# (1006, 129)

# %% [markdown]
# **PCA model using ilr transformation methods**

# %%
Model = PCA(n_components=129)
principalComponents = Model.fit_transform(X)
principalX = pd.DataFrame(data = principalComponents)
principalX.head(10)
# Out:
#          0         1         2    ...       126       127       128
# 0   2.603542 -3.433640  1.511299  ... -0.053239  0.038980 -0.007676
# 1   0.569068  0.989754 -4.557191  ...  0.032526  0.017125  0.006795
# 2   1.257616  1.539267 -0.373553  ... -0.009505  0.069625  0.030402
# 3  -0.552470 -4.050442  0.436187  ...  0.031804  0.000463  0.003677
# 4   6.486864 -0.462067 -3.401711  ...  0.041186 -0.002678  0.010299
# 5  -1.715785 -3.345691  2.510188  ... -0.098760  0.008846  0.049311
# 6   2.908968 -0.982295  4.940755  ...  0.040948  0.021348 -0.078524
# 7  10.064153  0.314231  3.655200  ...  0.046715 -0.115803 -0.026122
# 8   9.480584  0.472033  2.514428  ... -0.019888  0.023990 -0.069658
# 9   3.629304 -2.972152  0.912753  ...  0.056215  0.023161 -0.008073
#
# [10 rows x 129 columns]

# %%
print("Explained variation per principal component: {}".format(Model.explained_variance_ratio_))

# %%
total_variance = Model.explained_variance_ratio_.sum() * 100
total_variance
# Out:
# 99.99999999999999

# %%
import plotly.express as px
explained_var_cum = np.cumsum(Model.explained_variance_ratio_)
px.area(
    x=range(1, exp_var_cumul.shape[0] + 1),
    y=explained_var_cum,
    labels={"x": "Number of Components", "y": "Explained Variance"},
    width=700, height=400
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f59090a9-5753-4a21-8c59-a8f99f00c448" class="plotly-graph-div" style="height:400px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f59090a9-5753-4a21-8c59-a8f99f00c448")) {
#                     Plotly.newPlot(
#                         'f59090a9-5753-4a21-8c59-a8f99f00c448',
# ...

# %% [markdown]
# **PCA model using clr transformation**

# %%
X2 = coda.clr(df)
X2.shape
# Out:
# (1006, 130)

# %%
Model2 = PCA(n_components=130)
principalComponents = Model2.fit_transform(X2)
principalX2 = pd.DataFrame(data = principalComponents)
principalX2.head(2)
# Out:
#         0         1         2    ...       127       128           129
# 0  2.603542 -3.433640  1.511299  ...  0.038980 -0.007676 -3.866884e-14
# 1  0.569068  0.989754 -4.557191  ...  0.017125  0.006795  5.401105e-14
#
# [2 rows x 130 columns]

# %%
Model2.explained_variance_ratio_
np.sum(Model2.explained_variance_ratio_)
# Out:
# 1.0

# %%
total_variance = Model2.explained_variance_ratio_.sum() * 100
total_variance
# Out:
# 100.0

# %%
explained_var_cum = np.cumsum(Model2.explained_variance_ratio_)
px.area(
    x=range(1, explained_var_cum.shape[0] + 1),
    y=explained_var_cum,
    labels={"x": "Number of Components", "y": "Explained Variance"},
    width=700, height=400
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="77149303-e8d6-4f63-87e7-e11f4d7b2ba2" class="plotly-graph-div" style="height:400px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("77149303-e8d6-4f63-87e7-e11f4d7b2ba2")) {
#                     Plotly.newPlot(
#                         '77149303-e8d6-4f63-87e7-e11f4d7b2ba2',
# ...

# %%
Model2 = PCA(n_components=70)
principalComponents = Model2.fit_transform(X2)
principalX2 = pd.DataFrame(data = principalComponents)
total_variance = Model2.explained_variance_ratio_.sum() * 100
total_variance
# Out:
# 96.16862389985621

# %%
explained_var_cum = np.cumsum(Model2.explained_variance_ratio_)
px.area(
    x=range(1, explained_var_cum.shape[0] + 1),
    y=explained_var_cum,
    labels={"x": "Number of Components", "y": "Explained Variance"},
    width=700, height=400
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8e786bf5-376a-45fc-9c71-c237f7bb3458" class="plotly-graph-div" style="height:400px; width:700px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8e786bf5-376a-45fc-9c71-c237f7bb3458")) {
#                     Plotly.newPlot(
#                         '8e786bf5-376a-45fc-9c71-c237f7bb3458',
# ...
